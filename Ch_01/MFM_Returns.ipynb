# %%
#! pip install yfinance

# %%
import yfinance as yf
import dautil as dl
import numpy as np
import pandas as pd
#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
df = tickerData.history(period='1d', start='2010-1-1', end='2020-1-25')

#see your data
df
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2009-12-31   24.19   24.20   23.80   23.80  31929700        0.0             0
# 2010-01-04   23.91   24.29   23.89   24.17  38409100        0.0             0
# 2010-01-05   24.09   24.29   23.93   24.18  49749600        0.0             0
# 2010-01-06   24.11   24.27   23.83   24.03  58182400        0.0             0
# 2010-01-07   23.92   23.97   23.57   23.78  50559700        0.0             0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-01-17  166.10  166.15  164.12  165.78  34371700        0.0             0
# 2020-01-21  165.36  166.86  165.12  165.19  29517200        0.0             0
# 2020-01-22  166.08  166.17  164.37  164.39  24138800        0.0             0
# 2020-01-23  164.88  165.48  163.97  165.40  19680800        0.0             0
# 2020-01-24  166.19  166.21  163.15  163.74  24918100        0.0             0
#
# [2533 rows x 7 columns]

# %%
'''
#define the ticker symbol
tickerSymbol = 'MSFT'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get recommendation data for ticker
tickerData.recommendations
'''
# Out:
# "\n#define the ticker symbol\ntickerSymbol = 'MSFT'\n\n#get data on this ticker\ntickerData = yf.Ticker(tickerSymbol)\n\n#get recommendation data for ticker\ntickerData.recommendations\n"

# %%
# %%latex
#
# Simple return: $R_t=\frac{P_t - P_{t-1}}{P_{t-1}}$
# $\\$
# Log-return: $r_t = \log\left(\frac{P_t}{P_{t-1}}\right)=\log{P_t}-\log{P_{t-1}}$
# Out:
# Simple return: $R_t=\frac{P_t - P_{t-1}}{P_{t-1}}$
# $\\$
# Log-return: $r_t = \log\left(\frac{P_t}{P_{t-1}}\right)=\log{P_t}-\log{P_{t-1}}$

# %%
close = df["Close"]

simple_return = close.pct_change()

log_return = np.log(1+simple_ret)

# %%
import matplotlib.pyplot as plt   # Import matplotlib
# This line is necessary for the plot to appear in a Jupyter notebook
# %matplotlib inline
# Control the default size of figures in this Jupyter notebook
# %pylab inline

pylab.rcParams['figure.figsize'] = (15, 9)   # Change the size of plots

#apple["Adj. Close"].plot(grid = False) # Plot the adjusted closing price of AAPL

simple_return.plot()# Plot the lsimple return
log_return.plot() # Plot the logreturn
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\dell\AppData\Roaming\Python\Python37\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['close']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# <AxesSubplot:xlabel='Date'>

# %%
plt.plot(simple_return,log_return, 'o',c='blue')
plt.ylabel( 'Log-return' )
plt.xlabel( 'Simple return' )
#plt.legend(loc='upper center',bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=True)
plt.show()

# %%
# histogram
sns.distplot(log_return, kde=False, norm_hist=True,label='Log-returns') 
sns.distplot(simple_return, kde=False, norm_hist=True, label='Simple returns')  

legend(loc='upper left');

# plt.tight_layout()
# plt.savefig('images/ch1_im10.png')
plt.show()
